# %%
# %load_ext autoreload
# %autoreload 2
import os
import torch as t
from utils.config import opt
from model import FasterRCNNVGG16
from trainer import FasterRCNNTrainer
from data.util import  read_image
from utils.vis_tool import vis_bbox
from utils import array_tool as at
# %matplotlib inline

# %%
faster_rcnn = FasterRCNNVGG16()
trainer = FasterRCNNTrainer(faster_rcnn).cuda()
# Out:
# Setting up a new session...
# Traceback (most recent call last):
#   File "C:\Users\85266\anaconda3\lib\site-packages\urllib3\connection.py", line 159, in _new_conn
#     conn = connection.create_connection(
#   File "C:\Users\85266\anaconda3\lib\site-packages\urllib3\util\connection.py", line 84, in create_connection
#     raise err
#   File "C:\Users\85266\anaconda3\lib\site-packages\urllib3\util\connection.py", line 74, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\85266\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 670, in urlopen
#     httplib_response = self._make_request(
#   File "C:\Users\85266\anaconda3\lib\site-packages\urllib3\connectionpool.py", line 392, in _make_request
# ...

# %%
trainer.load(r'C:\simple-faster-rcnn-pytorch-master\home\cy\fasterrcnn_12222105_0.712649824453_caffe_pretrain.pth')
img = read_image(r'C:\Web_scrapper\northern_ave.jpg')
img = t.from_numpy(img)[None]
_bboxes, _labels, _scores = trainer.faster_rcnn.predict(img,visualize=True)
dp = vis_bbox(at.tonumpy(img[0]),
         at.tonumpy(_bboxes[0]),
         at.tonumpy(_labels[0]).reshape(-1),
         at.tonumpy(_scores[0]).reshape(-1))
dp2 = dp.get_figure()
dp2.savefig(r'C:\simple-faster-rcnn-pytorch-master\imgs\northern_ave_detected')
# Out:
# <AxesSubplot:>

# %%
img = read_image(r'C:\Web_scrapper\glendale_ave.jpg')
img = t.from_numpy(img)[None]
_bboxes, _labels, _scores = trainer.faster_rcnn.predict(img,visualize=True)
dp = vis_bbox(at.tonumpy(img[0]),
         at.tonumpy(_bboxes[0]),
         at.tonumpy(_labels[0]).reshape(-1),
         at.tonumpy(_scores[0]).reshape(-1))
dp2 = dp.get_figure()
dp2.savefig(r'C:\simple-faster-rcnn-pytorch-master\imgs\glendale_ave_detected')
# Out:
# <AxesSubplot:>

# %%
img = read_image(r'C:\Web_scrapper\camelback_rd.jpg')
img = t.from_numpy(img)[None]
_bboxes, _labels, _scores = trainer.faster_rcnn.predict(img,visualize=True)
dp = vis_bbox(at.tonumpy(img[0]),
         at.tonumpy(_bboxes[0]),
         at.tonumpy(_labels[0]).reshape(-1),
         at.tonumpy(_scores[0]).reshape(-1))
dp2 = dp.get_figure()
dp2.savefig(r'C:\simple-faster-rcnn-pytorch-master\imgs\camelback_rd_detected')
# Out:
# <AxesSubplot:>

# %%
img = read_image(r'C:\Web_scrapper\90th_st.jpg')
img = t.from_numpy(img)[None]
_bboxes, _labels, _scores = trainer.faster_rcnn.predict(img,visualize=True)
dp = vis_bbox(at.tonumpy(img[0]),
         at.tonumpy(_bboxes[0]),
         at.tonumpy(_labels[0]).reshape(-1),
         at.tonumpy(_scores[0]).reshape(-1))
dp2 = dp.get_figure()
dp2.savefig(r'C:\simple-faster-rcnn-pytorch-master\imgs\90th_st_detected')
# Out:
# <AxesSubplot:>

# %%
img = read_image(r'C:\Web_scrapper\via_de_ventura.jpg')
img = t.from_numpy(img)[None]
_bboxes, _labels, _scores = trainer.faster_rcnn.predict(img,visualize=True)
dp = vis_bbox(at.tonumpy(img[0]),
         at.tonumpy(_bboxes[0]),
         at.tonumpy(_labels[0]).reshape(-1),
         at.tonumpy(_scores[0]).reshape(-1))
dp2 = dp.get_figure()
dp2.savefig(r'C:\simple-faster-rcnn-pytorch-master\imgs\via_de_ventura_detected')
# Out:
# <AxesSubplot:>
